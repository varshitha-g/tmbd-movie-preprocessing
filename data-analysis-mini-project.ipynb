# %%
import pandas as pd

# %%
df = pd.read_csv("tmdb-movies.csv")

# %%
df[:5]
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline  ...  \
# 0              The park is open.  ...
# 1             What a Lovely Day.  ...
# 2     One Choice Can Destroy You  ...
# 3  Every generation has a story.  ...
# 4            Vengeance Hits Home  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
#  15  release_date          10866 non-null  object
#  16  vote_count            10866 non-null  int64
#  17  vote_average          10866 non-null  float64
#  18  release_year          10866 non-null  int64
#  19  budget_adj            10866 non-null  float64
#  20  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %%
df = df.filter(['id', 'budget', 'revenue', 'runtime', 'cast', 'genres', 'release_year', 'original_title'])

# %%
df.head()
# Out:
#        id     budget     revenue  runtime  \
# 0  135397  150000000  1513528810      124
# 1   76341  150000000   378436354      120
# 2  262500  110000000   295238201      119
# 3  140607  200000000  2068178225      136
# 4  168259  190000000  1506249360      137
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                       genres  release_year  \
# 0  Action|Adventure|Science Fiction|Thriller          2015
# 1  Action|Adventure|Science Fiction|Thriller          2015
# 2         Adventure|Science Fiction|Thriller          2015
# 3   Action|Adventure|Science Fiction|Fantasy          2015
# 4                      Action|Crime|Thriller          2015
#
#                  original_title
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7

# %%
df.isnull().sum()
# Out:
# id                 0
# budget             0
# revenue            0
# runtime            0
# cast              76
# genres            23
# release_year       0
# original_title     0
# dtype: int64

# %%
from matplotlib.pyplot import boxplot
from pylab import rcParams

# %%
df[df['budget'] <= 10000]
# Out:
#            id  budget   revenue  runtime  \
# 30     280996       0  29355203      103
# 36     339527       0  22354572      101
# 72     284289       0     45895       95
# 74     347096       0         0      108
# 75     308369       0         0      105
# ...       ...     ...       ...      ...
# 10860    5060       0         0       87
# 10861      21       0         0       95
# 10862   20379       0         0      176
# 10863   39768       0         0       94
# 10864   21449       0         0       80
#
#                                                     cast  \
# 30     Ian McKellen|Milo Parker|Laura Linney|Hattie M...
# 36     Abbie Cornish|Jeffrey Dean Morgan|Colin Farrel...
# 72     Michael Douglas|Jeremy Irvine|Hanna Mangan Law...
# 74     Melanie Stone|Kevin Sorbo|Adam Johnson|Jake St...
# 75     Thomas Mann|RJ Cyler|Olivia Cooke|Connie Britt...
# ...                                                  ...
# 10860  Kenneth Williams|Jim Dale|Harry H. Corbett|Joa...
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...
#
#                          genres  release_year                  original_title
# 30                Mystery|Drama          2015                      Mr. Holmes
# 36          Crime|Drama|Mystery          2015                          Solace
# 72                     Thriller          2015                Beyond the Reach
# 74     Action|Adventure|Fantasy          2015          Mythica: The Darkspore
# 75                 Comedy|Drama          2015  Me and Earl and the Dying Girl
# ...                         ...           ...                             ...
# 10860                    Comedy          1966             Carry On Screaming!
# 10861               Documentary          1966              The Endless Summer
# 10862    Action|Adventure|Drama          1966                      Grand Prix
# 10863            Mystery|Comedy          1966             Beregis Avtomobilya
# 10864             Action|Comedy          1966          What's Up, Tiger Lily?
#
# [5766 rows x 8 columns]

# %%
df.drop(df[df['budget'] < 10000].index, inplace = True)

# %%
rcParams['figure.figsize'] = 5, 15
boxplot = df.boxplot(column=['budget'])

# %%
rcParams['figure.figsize'] = 5, 15
boxplot = df.boxplot(column=['revenue'])

# %%
df[df['revenue'] <= 0]
# Out:
#            id    budget  revenue  runtime  \
# 48     265208  30000000        0       92
# 67     334074  20000000        0       96
# 93     307663  10000000        0       96
# 133    157827  11000000        0      109
# 145    294963   1800000        0      132
# ...       ...       ...      ...      ...
# 10827    2661   1377800        0      105
# 10832   23030   4800000        0      105
# 10841   42701     75000        0       82
# 10855   13343    700000        0       90
# 10865   22293     19000        0       74
#
#                                                     cast  \
# 48     Jason Statham|Michael Angarano|Milo Ventimigli...
# 67     Pierce Brosnan|Milla Jovovich|Dylan McDermott|...
# 93     Ambyr Childers|Thomas Jane|Bryan Greenberg|Bru...
# 133    Gabriel Byrne|Isabelle Huppert|Jesse Eisenberg...
# 145    Kurt Russell|Richard Jenkins|Matthew Fox|Lili ...
# ...                                                  ...
# 10827  Adam West|Burt Ward|Cesar Romero|Burgess Mered...
# 10832  Gregory Peck|Sophia Loren|Alan Badel|Kieron Mo...
# 10841  Will Hutchins|Millie Perkins|Jack Nicholson|Wa...
# 10855  Don Knotts|Joan Staley|Liam Redmond|Dick Sarge...
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...
#
#                                               genres  release_year  \
# 48                              Thriller|Crime|Drama          2015
# 67                             Crime|Thriller|Action          2015
# 93         Thriller|Science Fiction|Action|Adventure          2015
# 133                                            Drama          2015
# 145                   Horror|Western|Adventure|Drama          2015
# ...                                              ...           ...
# 10827  Family|Adventure|Comedy|Science Fiction|Crime          1966
# 10832                      Action|Adventure|Thriller          1966
# 10841                                        Western          1966
# 10855                  Comedy|Family|Mystery|Romance          1966
# 10865                                         Horror          1966
#
#                  original_title
# 48                    Wild Card
# 67                     Survivor
# 93                         Vice
# 133           Louder Than Bombs
# 145               Bone Tomahawk
# ...                         ...
# 10827                    Batman
# 10832                 Arabesque
# 10841              The Shooting
# 10855   The Ghost & Mr. Chicken
# 10865  Manos: The Hands of Fate
#
# [1272 rows x 8 columns]

# %%
df.drop(df[df['revenue'] <= 0].index, inplace = True)

# %%
rcParams['figure.figsize'] = 5, 15
boxplot = df.boxplot(column=['revenue'])

# %% [markdown]
# # Question-1

# %%
df['budget'].nlargest(3)
# Out:
# 2244    425000000
# 3375    380000000
# 7387    300000000
# Name: budget, dtype: int64

# %%
df[df['budget'] == 300000000]
# Out:
#        id     budget    revenue  runtime  \
# 7387  285  300000000  961000000      169
#
#                                                    cast  \
# 7387  Johnny Depp|Orlando Bloom|Keira Knightley|Geof...
#
#                         genres  release_year  \
# 7387  Adventure|Fantasy|Action          2007
#
#                                 original_title
# 7387  Pirates of the Caribbean: At World's End

# %%
df['budget'].nsmallest(3)
# Out:
# 1354    10000
# 7277    12000
# 7447    15000
# Name: budget, dtype: int64

# %%
df[df['budget'] == 15000]
# Out:
#          id  budget    revenue  runtime  \
# 7447  23827   15000  193355800       86
#
#                                                    cast          genres  \
# 7447  Katie Featherston|Micah Sloat|Mark Fredrichs|A...  Horror|Mystery
#
#       release_year       original_title
# 7447          2007  Paranormal Activity

# %% [markdown]
# # Question-2

# %%
df1 = df[(df['release_year']>=2000 ) & (df['release_year']<=2005)]

# %%
df1.head()
# Out:
#         id     budget    revenue  runtime  \
# 2633   120   93000000  871368364      178
# 2634   671  125000000  976475550      152
# 2635  1018   15000000   20117339      147
# 2636   141    6000000    1270522      113
# 2637   585  115000000  562816256       92
#
#                                                    cast  \
# 2633  Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...
# 2634  Daniel Radcliffe|Rupert Grint|Emma Watson|John...
# 2635  Naomi Watts|Laura Harring|Ann Miller|Dan Heday...
# 2636  Jake Gyllenhaal|Patrick Swayze|Drew Barrymore|...
# 2637  John Goodman|Billy Crystal|Mary Gibbs|Steve Bu...
#
#                                genres  release_year  \
# 2633         Adventure|Fantasy|Action          2001
# 2634         Adventure|Fantasy|Family          2001
# 2635           Thriller|Drama|Mystery          2001
# 2636            Fantasy|Drama|Mystery          2001
# 2637  Fantasy|Animation|Family|Comedy          2001
#
#                                          original_title
# 2633  The Lord of the Rings: The Fellowship of the Ring
# 2634           Harry Potter and the Philosopher's Stone
# 2635                                   Mulholland Drive
# 2636                                       Donnie Darko
# 2637                                     Monsters, Inc.

# %%
df1['number_of_words'] = df1.original_title.apply(lambda x: len(x.split()))
# Out:
# <ipython-input-23-814defeb8a03>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['number_of_words'] = df1.original_title.apply(lambda x: len(x.split()))

# %%
df1.head()
# Out:
#         id     budget    revenue  runtime  \
# 2633   120   93000000  871368364      178
# 2634   671  125000000  976475550      152
# 2635  1018   15000000   20117339      147
# 2636   141    6000000    1270522      113
# 2637   585  115000000  562816256       92
#
#                                                    cast  \
# 2633  Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...
# 2634  Daniel Radcliffe|Rupert Grint|Emma Watson|John...
# 2635  Naomi Watts|Laura Harring|Ann Miller|Dan Heday...
# 2636  Jake Gyllenhaal|Patrick Swayze|Drew Barrymore|...
# 2637  John Goodman|Billy Crystal|Mary Gibbs|Steve Bu...
#
#                                genres  release_year  \
# 2633         Adventure|Fantasy|Action          2001
# 2634         Adventure|Fantasy|Family          2001
# 2635           Thriller|Drama|Mystery          2001
# 2636            Fantasy|Drama|Mystery          2001
# 2637  Fantasy|Animation|Family|Comedy          2001
#
#                                          original_title  number_of_words
# 2633  The Lord of the Rings: The Fellowship of the Ring               10
# 2634           Harry Potter and the Philosopher's Stone                6
# 2635                                   Mulholland Drive                2
# 2636                                       Donnie Darko                2
# 2637                                     Monsters, Inc.                2

# %%
df1["number_of_words"].mean()
# Out:
# 2.690537084398977

# %% [markdown]
# # Question-3

# %%
df['genres'] = df.genres.str.split('|')

# %%
df.head()
# Out:
#        id     budget     revenue  runtime  \
# 0  135397  150000000  1513528810      124
# 1   76341  150000000   378436354      120
# 2  262500  110000000   295238201      119
# 3  140607  200000000  2068178225      136
# 4  168259  190000000  1506249360      137
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                            genres  release_year  \
# 0  [Action, Adventure, Science Fiction, Thriller]          2015
# 1  [Action, Adventure, Science Fiction, Thriller]          2015
# 2          [Adventure, Science Fiction, Thriller]          2015
# 3   [Action, Adventure, Science Fiction, Fantasy]          2015
# 4                       [Action, Crime, Thriller]          2015
#
#                  original_title
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7

# %%
df['cast'] = df.cast.str.split('|')

# %%
df.head()
# Out:
#        id     budget     revenue  runtime  \
# 0  135397  150000000  1513528810      124
# 1   76341  150000000   378436354      120
# 2  262500  110000000   295238201      119
# 3  140607  200000000  2068178225      136
# 4  168259  190000000  1506249360      137
#
#                                                 cast  \
# 0  [Chris Pratt, Bryce Dallas Howard, Irrfan Khan...
# 1  [Tom Hardy, Charlize Theron, Hugh Keays-Byrne,...
# 2  [Shailene Woodley, Theo James, Kate Winslet, A...
# 3  [Harrison Ford, Mark Hamill, Carrie Fisher, Ad...
# 4  [Vin Diesel, Paul Walker, Jason Statham, Miche...
#
#                                            genres  release_year  \
# 0  [Action, Adventure, Science Fiction, Thriller]          2015
# 1  [Action, Adventure, Science Fiction, Thriller]          2015
# 2          [Adventure, Science Fiction, Thriller]          2015
# 3   [Action, Adventure, Science Fiction, Fantasy]          2015
# 4                       [Action, Crime, Thriller]          2015
#
#                  original_title
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7

# %%
df1 = df.explode('cast')

# %%
df1.head()
# Out:
#        id     budget     revenue  runtime                 cast  \
# 0  135397  150000000  1513528810      124          Chris Pratt
# 0  135397  150000000  1513528810      124  Bryce Dallas Howard
# 0  135397  150000000  1513528810      124          Irrfan Khan
# 0  135397  150000000  1513528810      124    Vincent D'Onofrio
# 0  135397  150000000  1513528810      124        Nick Robinson
#
#                                            genres  release_year  \
# 0  [Action, Adventure, Science Fiction, Thriller]          2015
# 0  [Action, Adventure, Science Fiction, Thriller]          2015
# 0  [Action, Adventure, Science Fiction, Thriller]          2015
# 0  [Action, Adventure, Science Fiction, Thriller]          2015
# 0  [Action, Adventure, Science Fiction, Thriller]          2015
#
#    original_title
# 0  Jurassic World
# 0  Jurassic World
# 0  Jurassic World
# 0  Jurassic World
# 0  Jurassic World

# %% [markdown]
# VIN DIESEL

# %%
df2 = df1[df1['cast'] == 'Vin Diesel']

# %%
df2.head()
# Out:
#           id     budget     revenue  runtime        cast  \
# 4     168259  190000000  1506249360      137  Vin Diesel
# 41    274854   90000000   140396650      106  Vin Diesel
# 630   118340  170000000   773312399      121  Vin Diesel
# 1539   13804   85000000   363164265      107  Vin Diesel
# 2438   10386   70000000    23159305       86  Vin Diesel
#
#                                                  genres  release_year  \
# 4                             [Action, Crime, Thriller]          2015
# 41                         [Fantasy, Action, Adventure]          2015
# 630                [Action, Science Fiction, Adventure]          2014
# 1539                   [Action, Crime, Drama, Thriller]          2009
# 2438  [Adventure, Animation, Family, Fantasy, Scienc...          1999
#
#                original_title
# 4                   Furious 7
# 41      The Last Witch Hunter
# 630   Guardians of the Galaxy
# 1539           Fast & Furious
# 2438           The Iron Giant

# %%
df2 = df2.explode('genres')[:5]

# %%
df2.genres.mode()
# Out:
# 0    Action
# dtype: object

# %%
df2['genres'].value_counts()
# Out:
# Action      2
# Thriller    1
# Fantasy     1
# Crime       1
# Name: genres, dtype: int64

# %% [markdown]
# EMMA WATSON

# %%
df3 = df1[(df1['cast'] == 'Emma Watson' )]

# %%
df3.head()
# Out:
#          id     budget    revenue  runtime         cast  \
# 686   86834  125000000  362637473      139  Emma Watson
# 1389    767  250000000  933959197      153  Emma Watson
# 1923  12444  250000000  954305868      146  Emma Watson
# 2634    671  125000000  976475550      152  Emma Watson
# 3020  10199   60000000   50877145      100  Emma Watson
#
#                             genres  release_year  \
# 686             [Drama, Adventure]          2014
# 1389  [Adventure, Fantasy, Family]          2009
# 1923  [Adventure, Fantasy, Family]          2010
# 2634  [Adventure, Fantasy, Family]          2001
# 3020   [Animation, Comedy, Family]          2008
#
#                                     original_title
# 686                                           Noah
# 1389        Harry Potter and the Half-Blood Prince
# 1923  Harry Potter and the Deathly Hallows: Part 1
# 2634      Harry Potter and the Philosopher's Stone
# 3020                        The Tale of Despereaux

# %%
df3 = df3.explode('genres')

# %%
df3.genres.mode()
# Out:
# 0    Adventure
# 1       Family
# dtype: object

# %%
df3['genres'].value_counts()
# Out:
# Adventure    9
# Family       9
# Fantasy      8
# Drama        3
# Animation    1
# Comedy       1
# Mystery      1
# Romance      1
# Crime        1
# Name: genres, dtype: int64

# %% [markdown]
# # Question-4

# %%
minvalue = df['revenue'].min()

# %%
minvalue
# Out:
# 2

# %%
maxvalue = df['revenue'].max()

# %%
maxvalue
# Out:
# 2781505847

# %%
df[df['revenue'] == 2]
# Out:
#          id   budget  revenue  runtime  \
# 5067  13537  6000000        2       94
# 8142   2293  6000000        2       94
#
#                                                    cast             genres  \
# 5067  [Hayden Christensen, Peter Sarsgaard, ChloÃ« S...   [Drama, History]
# 8142  [Jason Lee, Jeremy London, Shannen Doherty, Cl...  [Romance, Comedy]
#
#       release_year   original_title
# 5067          2003  Shattered Glass
# 8142          1995         Mallrats

# %%
df[df['revenue'] == 2781505847]
# Out:
#          id     budget     revenue  runtime  \
# 1386  19995  237000000  2781505847      162
#
#                                                    cast  \
# 1386  [Sam Worthington, Zoe Saldana, Sigourney Weave...
#
#                                              genres  release_year  \
# 1386  [Action, Adventure, Fantasy, Science Fiction]          2009
#
#      original_title
# 1386         Avatar

# %% [markdown]
# # Question-5

# %%
#df1 = df[(df['release_year']>=2000 ) & (df['release_year']<=2005)]
dfr = df[df['release_year'] == 2006]

# %%
dfr.head()
# Out:
#          id     budget     revenue  runtime  \
# 6554    834   50000000   111340801      106
# 6555     58  200000000  1065659812      151
# 6556    920  120000000   461983149      117
# 6557  36557  150000000   599045960      144
# 6558    591  125000000   758239851      149
#
#                                                    cast  \
# 6554  [Kate Beckinsale, Scott Speedman, Tony Curran,...
# 6555  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 6556  [Owen Wilson, Paul Newman, Bonnie Hunt, Larry ...
# 6557  [Daniel Craig, Eva Green, Mads Mikkelsen, Judi...
# 6558  [Tom Hanks, Audrey Tautou, Ian McKellen, Paul ...
#
#                                             genres  release_year  \
# 6554  [Fantasy, Action, Science Fiction, Thriller]          2006
# 6555                  [Adventure, Fantasy, Action]          2006
# 6556        [Animation, Adventure, Comedy, Family]          2006
# 6557                 [Adventure, Action, Thriller]          2006
# 6558                           [Thriller, Mystery]          2006
#
#                                   original_title
# 6554                       Underworld: Evolution
# 6555  Pirates of the Caribbean: Dead Man's Chest
# 6556                                        Cars
# 6557                               Casino Royale
# 6558                           The Da Vinci Code

# %%
dfr['runtime'].mean()
# Out:
# 108.18934911242603
